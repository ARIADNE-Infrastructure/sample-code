# %% [markdown]
# # User guide for the ARIADNEplus Knowledge Base (GraphDB)
#
# ## Version 1.1
# Changes from 1.0:
#
# - [The endpoints](#The-endpoints): Staging GraphDB is accessible only from trusted networks
# - [Organisation of the data](#Organisation-of-the-data):
#  - Fixed and shorten URI in table in section
#  - Added table as image to avoid bad rendering in PDF
# - [Sample queries](#Sample-queries): deleted trailing cell code
# - The whole notebook was re-run on 23/10/2023
#
# ### Authors: Alessia Bardi (CNR-ISTI), Enrico Ottonello (CNR-ISTI)
#
# ## Table of contents
#
# - [The endpoints](#The-endpoints)
# - [Using GraphDB workbench](#Using-GraphDB-workbench)
# - [Organisation of the data](#Organisation-of-the-data)
# - [Querying GraphDB programmatically](#Querying-GraphDB-programmatically)
#  - [Java](#Java)
#  - [Python](#Python)
# - [Sample queries](#Sample-queries)
#
# ## The endpoints
#
# * Production endpoint: https://graphdb.ariadne.d4science.org/ (non authenticated read-only access). Content from the production endpoint is fed to the public portal
# * Staging endpoint: https://graphdb-test.ariadne.d4science.org/ (non authenticated read-only access) - non stable content, may include test data, mainly to be used by consortium members for quality checks before data publication on the public endpoint and public portal. Content from the staging graphDB is fed to the staging portal. Access is allowed only from authorised networks.
#
# Both endpoints run on [GraphDB Free](https://www.ontotext.com/products/graphdb/graphdb-free/) version 9.0.0
#
# | Endpoint      | Name of the repository | Type of content      | Suggested for |  Software |
# | ----------- | ----------- | ----------- | ----------- | ----------- |
# | staging      | ariadneplus-ts01       | Non stable, test | Technical tests, query syntax checks | GraphDB Free version 9.0.0 |
# | production   | ariadneplus-pr01        | Stable, approved by providers | Data access | GraphDB Free version 9.0.0 |
#
#
# ## Using GraphDB workbench
#
# Open the URL of one of the endpoints with your browser to access the workbench (fig. 1)
#
# 1. In case you do not see the Active repository, choose it in the top-right menu
# 2. On the left menu you have all functions: you are allowed to use any read function
# 3. Full documentation provided by GraphDB available under the “Help” menu on the left
# 4. “View resource”: type the URI of a known resource to get it: click on Visual for a visual representation, Text for a textual/tabular representation
# 5. Explore the data selecting an option from the left menu item named “Explore”
# 6. Run SPARQL queries selecting the left menu item named “SPARQL”. The page that opens is an advanced SPARQL query editor that you can also access directly with the URL <endpoint_url>/sparql
#
# | ![fig1](workbench.jpg) |
# |:--:|
# | <b>Figure 1 Home page of GraphDB Workbench</b>|
#
#
# ## Organisation of the data
#
# Data on GraphDB is organised in such a way that it is possible to perform incremental updates of its content. This has been done by using the concept of “named graph” in a specific way to enable continuous updates and enrichments to aggregated data. For details, please consult [D12.2 Mid-term report on data integration](https://doi.org/10.5281/zenodo.4922902) (Section 3.1). In brief:
#
# * Table 1 below summarises how the data on GraphDB is organised (for readibility we omit the first part of the URI, which is always https://ariadne-infrastructure.eu/)
#
# | Named graph      | Template URI\[^1\] | Example URI      | What is it |  How many |
# | ----------- | ----------- | ----------- | ----------- | ----------- |
# | Provenance      | N/A       | datasourceApis | A special graph to keep provenance information. It contains information about which endpoints and which datasets have been added to GraphDB and when | One |
# | Core data   | api_________::ariadne_plus::<providerAcronym>::<datasetId>        | api_________::ariadne_plus::hnm::hnmad | One named graph per dataset[^2] | One per dataset [^3] |
# | AAT matching rules   | api_________::ariadne_plus::<providerAcronym>::aat        | api_________::ariadne_plus::hnm::aat | One named graph with the matches between local subjects and Getty AAT terms[^4] | One per provider (optional[^5]) |
# | AAT enrichments   | ariadneplus::<providerAcronym>::aatplus        | ariadneplus::hnm::aatplus | One named graph containing the triples inferred by intersecting the aggregated data and Getty AAT based on the provided matching | One per provider (optional) |
# | PeriodO  provider’s terms   | ariadneplus::<providerAcronym>::periodo        | ariadneplus::hnm::periodo | One named graph with PeriodO terms covered by the provider | One per provider (optional[^6]) |
# | ARIADNE’s PeriodO terms   | N/A       | ariadne/periodo | PeriodO collection created during the previous Ariadne project[^7] | One |
# | PeriodO enrichments   | ariadneplus::<providerAcronym>::periodoplus       | ariadneplus::hnm::periodoplus| One named graph containing the triples inferred by intersecting the aggregated data and the PeriodO collection relevant for the provider | One per provider (optional) |
#
#  [^1] All URIs shall be considered as a mere identifier local to GraphDB and, although they start with ‘https’, they do not currently resolve to any content served by the HTTPS protocol.
#
#  [^2] where “dataset” is to be intended as a set of metadata records from a provider
#
#  [^3] One provider can have many “datasets” (i.e. many named graphs); one “dataset” (i.e. one named graph) has only one provider.
#
#  [^4] as generated using the Vocabulary Matching Tool
#
#  [^5] The existence of this graph is optional, as the transformed RDF triples may already contain terms of Getty AAT.
#
#  [^6] The existence of this graph is optional, as the transformed RDF triples may already contain terms and dates of PeriodO or the provider might not have a dedicated PeriodO collection to import
#
#  [^7] http://n2t.net/ark:/99152/p0qhb66
#
# * Figure 2 shows the set of named graphs available for the HNM provider (as an example).
# * Figure 3 instead show part of the content of the provenance graph that tells us that the data collected from the dataset with internal identifier api_________::ariadne_plus::ads::1 belongs to Archaeology Data Service and that the content from it was inserted into GraphDB in 2020-10-07. Please note that the subject of the triples (https://ariadne-infrastructure.eu/api_________::ariadne_plus::ads::1) has the same URI as the named graph that groups all RDF triples generated from the data collected from this API.
#
# | ![fig2](named-graphs.png) |
# |:--:|
# | <b>Figure 2 The named graphs associated to data provided by HNM</b>|
#
# | ![fig3](triples.png) |
# |:--:|
# | <b>Figure 3 Sample triples in the “provenance graph”</b>|
#
# ## Querying GraphDB programmatically
#
# GraphDB provides
#
# * the Workbench REST API, documented at https://graphdb.ariadne.d4science.org/webapi (fig. 4)
# * RDF4J API as documented at https://graphdb.ontotext.com/documentation/9.0/free/using-graphdb-with-the-rdf4j-api.html
#
# | ![fig4](rest.png) |
# |:--:|
# | <b>Figure 4 Documentation on graphDB REST RDF4J API</b>|
#
# ### Java
#
# You can query the endpoint with any RDF4J compliant client. For example the [Eclipse RDF4J API](https://rdf4j.org/) for the Java programming language.
# Sample code for connecting and querying the staging endpoint with the Java RDF4J API is available at https://github.com/ARIADNE-Infrastructure/sample-code .
# The code includes a generic GraphDBReader class with an example of TupleQuery on the provenance graph and one CONSTRUCT query for one of the collection records provided by ADS.
#
# In addition, some simple but useful SPARQL queries are available in a dedicated folder.
# In the following interactive paragraphs we mention some examples, but additional queries may be added to the github repositories based on users’ requests for support.
#
#
# ### Python
#
# Check out the following interactive paragraphs, which uses the [SPARQLWrapper library](https://github.com/RDFLib/sparqlwrapper).

# %%
#install libraries
# !pip install rdflib
# !pip install SPARQLWrapper
# !pip install prettytable
# Out:
# Requirement already satisfied: rdflib in /opt/conda/lib/python3.8/site-packages (5.0.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.8/site-packages (from rdflib) (2.4.7)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from rdflib) (1.15.0)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.8/site-packages (from rdflib) (0.6.0)
# Requirement already satisfied: SPARQLWrapper in /opt/conda/lib/python3.8/site-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /opt/conda/lib/python3.8/site-packages (from SPARQLWrapper) (5.0.0)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (2.4.7)
# Requirement already satisfied: isodate in /opt/conda/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (0.6.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (1.15.0)
# Collecting prettytable
#   Using cached prettytable-3.4.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prettytable) (0.2.5)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.4.1

# %%
#imports
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint

# %%
sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
    PREFIX  aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
    SELECT *
    WHERE { 
        # ?c rdf:type aocat:AO_Collection .
        # ?c ?p ?o .
    }
    LIMIT 10
''')
sparql.setReturnFormat(JSON)
#Short SPARQL queries can be sent with a GET, for long queries, better use a POST by uncommenting the line below
# sparql.setMethod('POST')
qres = sparql.query().convert()

# To view the raw output, uncomment the line below
# pprint(qres)
#For more readable triples, let's remove the base namespace from the predicates
for result in qres['results']['bindings']:
    s,p,o = result['c']['value'], result['p']['value'].rsplit('/', 1)[1],result['o']['value']
    print(f'{s} - {p} - {o}' )
# Out:
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - 22-rdf-syntax-ns#type - https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/AO_Collection
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - rdf-schema#label - Collection  10.5284
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Artefact
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Inscription
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Fieldwork%20archive
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Scientific%20analysis
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Burial
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_ARIADNE_subject - https://ariadne-infrastructure.eu/aocat/Concept/AO_Subject/Date
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_contributor - https://ariadne-infrastructure.eu/aocat/Agent/Various
# https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F - has_publisher - https://ariadne-infrastructure.eu/aocat/Agent/Archaeology%20Data%20Service

# %%
import xml.dom.minidom
from IPython.display import Code

sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
    PREFIX  aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
    SELECT ?c
    WHERE { 
        # ?c rdf:type aocat:AO_Collection .
    }
    LIMIT 10
''')
sparql.setReturnFormat('xml')
qres = sparql.query().convert()

# for a real pretty print of XML we need to use IPython.display Code
Code(qres.toprettyxml(), language='xml')
# Out:
# <?xml version="1.0" ?>
# <sparql xmlns="http://www.w3.org/2005/sparql-results#">
#
#
# 	<head>
#
#
# 		<variable name="c"/>
#
#
# 	</head>
#
#
# 	<results>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/AC6671C7-FD6D-311D-98D0-F635D5EFAA4F</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/F9550D50-B36A-3897-90FA-0D71F9783034</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/CECFB7F8-EA63-34F5-81CE-F1E89A94DA80</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/F8FAC6C9-8E3D-355C-83E5-B162FC005EC2</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/849B1C0F-4C5F-3D8C-9082-CA60DBB4F557</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/F18A0D06-2A86-334A-AA1E-046E32A34327</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/B1E1FD6B-42C6-35B6-82E8-06E0082CCC71</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/58114087-BD7B-3ECC-9B46-A48C8BB36F6C</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/5DE1B42A-6A52-3164-A1F3-E17BD6A2D082</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 		<result>
#
#
# 			<binding name="c">
#
#
# 				<uri>https://ariadne-infrastructure.eu/aocat/Collection/ADS/2ACC7451-9747-3346-B79E-F13DE4994E37</uri>
#
#
# 			</binding>
#
#
# 		</result>
#
#
# 	</results>
#
#
# </sparql>

# %% [markdown]
# ## Sample queries
#
# Let's try some sample queries. You can find more on [sample-queries folder on github](https://github.com/ARIADNE-Infrastructure/sample-code/tree/master/src/main/resources/ariadneplus/sparql-queries). In the following we mention some examples, but additional queries may be added to the github repositories based on users’ requests for support.
#
# ### Get titles of 10 resources whose contributor is the Archaeology Data Service

# %%
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint

sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
    PREFIX aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?title  WHERE {
        # ?resourceIRI aocat:has_contributor ?contributor .
        # ?contributor rdfs:label "Archaeology Data Service" .
        # ?resourceIRI aocat:has_title ?title
    }
    LIMIT 10
''')
sparql.setReturnFormat(JSON)
qres = sparql.query().convert()

# To view the raw output, uncomment the line below
# pprint(qres)
#For more readable triples, let's remove the base namespace from the predicates
print('Titles of resources with ADS as contributor')
print('-------------------------------------------')
for result in qres['results']['bindings']:
    t = result['title']['value']
    print(f'{t}' )
# Out:
# Titles of resources with ADS as contributor
# -------------------------------------------
# Day of Archaeology Archive
# Gwynedd Regional HER
# Glamorgan-Gwent HER
# York Archive Gazetteer
# Englands Rock Art
# Northern Ireland Sites and Monuments Record
# Parks and Gardens Data Service
# Greater London Sites and Monuments Record
# Defence of Britain Archive
# Greater London Sites and Monuments Record

# %% [markdown]
# ### Count number of Collections by provider

# %%
from prettytable import PrettyTable
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint


sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
    PREFIX aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?name (COUNT(?c) AS ?num_collections) WHERE {
        # ?c rdf:type aocat:AO_Collection .
        # ?c aocat:has_publisher ?publisher .
        # ?publisher aocat:has_name ?name .
    } GROUP BY ?name
''')

sparql.setReturnFormat(JSON)
qres = sparql.query().convert()

t = PrettyTable(['Provider', 'Num Collections'])
total = 0
for result in qres['results']['bindings']:
    contrib,count = result['name']['value'],result['num_collections']['value']
    t.add_row([contrib, count])
    total += int(count)

print(f'Total number of collections: {total}')
print(t)
# Out:
# Total number of collections: 60302
# +------------------------------------------------------------------------------+-----------------+
# |                                   Provider                                   | Num Collections |
# +------------------------------------------------------------------------------+-----------------+
# |                           Archaeology Data Service                           |        32       |
# | National Institute of Archaeology with Museum, Bulgarian Academy of Sciences |        1        |
# |                             University of Patras                             |        3        |
# |                        Swedish National Data Service                         |       484       |
# |                      Swedish Rock Art Research Archives                      |        1        |
# |                                   ZRC SAZU                                   |        2        |
# |                                     HNM                                      |      59686      |
# |                 Data Archiving and Networked Services (DANS)                 |        2        |
# |                 Data Archiving and Networked Services (DANS)                 |        2        |
# |             International Association for Classical Archaeology              |        1        |
# |                                 Not provided                                 |        1        |
# |       Archaeological Information System of the Czech Republic (AIS CR)       |        1        |
# |                Heidelberg Academy of Sciences and Humanities                 |        1        |
# |                Heidelberg Academy of Sciences and Humanities                 |        1        |
# |                              Aarhus University                               |        1        |
# |                                    CENIEH                                    |        3        |
# |                                     INFN                                     |        43       |
# |                    Institute of Archaeology Vasile Pârvan                    |        2        |
# |                             The Cyprus Institute                             |        1        |
# |                             IDACOR (CONICET/UNC)                             |        2        |
# |           Nara National Research Institute for Cultural Properties           |        1        |
# |      Institut national de recherches archéologiques préventives (Inrap)      |        1        |
# |         ICCD - Istituto Centrale per il Catalogo e la Docmentazione          |        22       |
# |                                British Museum                                |        1        |
# |                        Historic Environment Scotland                         |        1        |
# |                    National Heritage Institute - Romania                     |        1        |
# |                Institutul Național al Patrimoniului - România                |        1        |
# |                      CEIPAC - Universitat de Barcelona                       |        1        |
# |                         Center for Digital Antiquity                         |        1        |
# |                         Center for Digital Antiquity                         |        1        |
# |    Consortium MASA - Mémoire des Archéologues et des Sites Archéologiques    |        1        |
# +------------------------------------------------------------------------------+-----------------+

# %% [markdown]
# ### Get number of resources by provider and ARIADNE subjects

# %%
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint


sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
PREFIX aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT (count(?resource) AS ?cnt) ?publisherName ?asl  WHERE {
    # ?resource aocat:has_publisher ?publisher . 
    # ?publisher aocat:has_name ?publisherName .
    # ?resource aocat:has_ARIADNE_subject ?as .
    # ?as rdfs:label ?asl
}
GROUP BY ?publisherName ?asl
''')

sparql.setReturnFormat(JSON)
qres = sparql.query().convert()

t = PrettyTable(['Provider', 'ARIADNE subjects', 'Count'])

for result in qres['results']['bindings']:
    t.add_row([result['publisherName']['value'], result['asl']['value'], result['cnt']['value']])

print(t)
# Out:
# +------------------------------------------------------------------------------+------------------+--------+
# |                                   Provider                                   | ARIADNE subjects | Count  |
# +------------------------------------------------------------------------------+------------------+--------+
# |                           Archaeology Data Service                           |     Artefact     |  4706  |
# |                           Archaeology Data Service                           |   Inscription    | 26315  |
# |                           Archaeology Data Service                           |       Date       |  9026  |
# |                           Archaeology Data Service                           | Fieldwork report | 63596  |
# |                           Archaeology Data Service                           |  Site/monument   | 804458 |
# |                           Archaeology Data Service                           |     Maritime     |   81   |
# |                           Archaeology Data Service                           |     Rock Art     |  1582  |
# |                           Archaeology Data Service                           |    Fieldwork     | 189803 |
# | National Institute of Archaeology with Museum, Bulgarian Academy of Sciences |  Site/monument   |  1952  |
# |                             University of Patras                             |       Date       |   1    |
# |                      Swedish Rock Art Research Archives                      |     Rock Art     | 25223  |
# |                                   ZRC SAZU                                   |  Site/monument   |  8911  |
# |                                     HNM                                      |    Fieldwork     | 59686  |
# |                 Data Archiving and Networked Services (DANS)                 |     Artefact     | 49935  |
# |                 Data Archiving and Networked Services (DANS)                 |     Artefact     | 49935  |
# |                 Data Archiving and Networked Services (DANS)                 | Fieldwork report | 38279  |
# |                 Data Archiving and Networked Services (DANS)                 | Fieldwork report | 38279  |
# |             International Association for Classical Archaeology              |  Site/monument   | 14359  |
# |             International Association for Classical Archaeology              |    Fieldwork     | 14358  |
# |                                 Not provided                                 |  Site/monument   |   1    |
# |                                 Not provided                                 |     Artefact     |   1    |
# |                                 Not provided                                 |    Fieldwork     |   1    |
# |       Archaeological Information System of the Czech Republic (AIS CR)       |  Site/monument   |  2055  |
# |       Archaeological Information System of the Czech Republic (AIS CR)       |     Artefact     |   61   |
# |       Archaeological Information System of the Czech Republic (AIS CR)       |    Fieldwork     | 129126 |
# |                Heidelberg Academy of Sciences and Humanities                 |  Site/monument   |  7537  |
# |                Heidelberg Academy of Sciences and Humanities                 |  Site/monument   |  7537  |
# |                              Aarhus University                               |     Artefact     |  8687  |
# |                                    CENIEH                                    | Fieldwork report |  705   |
# |                                     INFN                                     |       Date       |   20   |
# |                    Institute of Archaeology Vasile Pârvan                    |  Site/monument   |  136   |
# |                             IDACOR (CONICET/UNC)                             |    Fieldwork     |  2220  |
# |      Institut national de recherches archéologiques préventives (Inrap)      | Fieldwork report | 38073  |
# |                                    CENIEH                                    |    Fieldwork     |   12   |
# |         ICCD - Istituto Centrale per il Catalogo e la Docmentazione          |     Artefact     |   22   |
# |                                British Museum                                |     Artefact     | 476224 |
# |                        Historic Environment Scotland                         |  Site/monument   | 334636 |
# |                        Historic Environment Scotland                         |     Maritime     | 33379  |
# |                    National Heritage Institute - Romania                     |  Site/monument   | 18279  |
# |                Institutul Național al Patrimoniului - România                |  Site/monument   | 18279  |
# |                             IDACOR (CONICET/UNC)                             |     Artefact     |  282   |
# |                      CEIPAC - Universitat de Barcelona                       |   Inscription    | 57089  |
# |    Consortium MASA - Mémoire des Archéologues et des Sites Archéologiques    |     Artefact     |   2    |
# |    Consortium MASA - Mémoire des Archéologues et des Sites Archéologiques    |    Fieldwork     |   2    |
# |    Consortium MASA - Mémoire des Archéologues et des Sites Archéologiques    |   Inscription    |   1    |
# +------------------------------------------------------------------------------+------------------+--------+

# %% [markdown]
# ### Records from ADS, Aarhus or DANS that are with ARIADNE_subject = “Artefact” and derived_subject = “Brooch” (http://vocab.getty.edu/aat/300045995)

# %%
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint


sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
PREFIX aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX periodo: <http://n2t.net/ark:/99152/p0v#>
PREFIX dcterms: <http://purl.org/dc/terms/>
SELECT ?provider ?country (count(distinct ?resource) AS ?cnt)   WHERE {
    # ?resource aocat:has_publisher ?publisher . 
    # ?publisher rdfs:label ?provider .
    # ?resource aocat:has_derived_subject <http://vocab.getty.edu/aat/300045995> .
    # ?resource aocat:has_temporal_coverage ?tc .
    # ?tc aocat:has_period ?periodo .
    # ?periodo dcterms:spatial ?spatial .
    # ?spatial skos:prefLabel ?country
    FILTER(?provider="Archaeology Data Service" || ?provider="Data Archiving and Networked Services (DANS)" || ?provider="Aarhus University")
}
GROUP BY ?country ?provider
''')

sparql.setReturnFormat(JSON)
qres = sparql.query().convert()

print('Records from ADS, Aarhus or DANS that are with ARIADNE_subject = “Artefact” and derived_subject = “Brooch” by country')
t = PrettyTable(['Provider', 'Country', 'Count'])

for result in qres['results']['bindings']:
    t.add_row([result['provider']['value'], result['country']['value'], result['cnt']['value']])

print(t)
# Out:
# Records from ADS, Aarhus or DANS that are with ARIADNE_subject = “Artefact” and derived_subject = “Brooch” by country
# +----------------------------------------------+----------------+-------+
# |                   Provider                   |    Country     | Count |
# +----------------------------------------------+----------------+-------+
# |           Archaeology Data Service           |    Hungary     |  1971 |
# |           Archaeology Data Service           | United Kingdom |  2452 |
# |           Archaeology Data Service           |      Asia      |  343  |
# |           Archaeology Data Service           |     Europe     |  343  |
# |           Archaeology Data Service           |     Earth      |   18  |
# |           Archaeology Data Service           |    Scotland    |  2394 |
# | Data Archiving and Networked Services (DANS) |  Netherlands   |  9740 |
# |              Aarhus University               |    Denmark     |   13  |
# +----------------------------------------------+----------------+-------+

# %% [markdown]
# ### Derived subjects by provider for Fieldwork and Fieldwork report resources

# %%
from rdflib import Graph
from SPARQLWrapper import SPARQLWrapper, JSON, N3
from pprint import pprint


sparql = SPARQLWrapper('https://graphdb.ariadne.d4science.org/repositories/ariadneplus-pr01')
sparql.setQuery('''
PREFIX aocat: <https://www.ariadne-infrastructure.eu/resource/ao/cat/1.1/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX periodo: <http://n2t.net/ark:/99152/p0v#>
PREFIX dcterms: <http://purl.org/dc/terms/>
SELECT ?provider ?dsl (count(distinct ?resource) AS ?cnt)   WHERE {
    # ?resource aocat:has_publisher ?publisher . 
    # ?publisher rdfs:label ?provider .
    # ?resource aocat:has_ARIADNE_subject ?as .
    # ?as rdfs:label ?asl .
    # ?resource aocat:has_derived_subject ?ds .
    # ?ds skos:prefLabel ?dsl .
    FILTER(?asl = 'Fieldwork report'@en || ?asl = 'Fieldwork'@en)
}
GROUP BY ?dsl ?provider
ORDER BY desc(?cnt)
''')

sparql.setReturnFormat(JSON)
qres = sparql.query().convert()

print('Derived subjects by provider for Fieldwork and Fieldwork report resources')
  
t = PrettyTable(['Provider', 'Derived subject label', 'Count'])

for result in qres['results']['bindings']:
    t.add_row([result['provider']['value'], result['dsl']['value'], result['cnt']['value']])

print(t)
# Out:
# Derived subjects by provider for Fieldwork and Fieldwork report resources
# +--------------------------------------------------------------------+---------------------------------------------------------------------+-------+
# |                              Provider                              |                        Derived subject label                        | Count |
# +--------------------------------------------------------------------+---------------------------------------------------------------------+-------+
# |                               AIS CR                               |                               trenches                              | 60227 |
# |                               AIS CR                               |                        museums (institutions)                       | 54978 |
# |                                HNM                                 |                         settlement patterns                         | 38277 |
# |                               AIS CR                               |                  research institutes (institutions)                 | 37033 |
# |                               AIS CR                               |                   settlement (population activity)                  | 32536 |
# |                               AIS CR                               |                             land surveys                            | 28320 |
# |                      Archaeology Data Service                      |                          pits (earthworks)                          | 22943 |
# |                      Archaeology Data Service                      |                               ditches                               | 22152 |
# |                               AIS CR                               |                          cuts (earthworks)                          | 13369 |
# |                               AIS CR                               |                       nonprofit organizations                       | 12946 |
# |                               AIS CR                               |                          pits (earthworks)                          | 11825 |
# |                               AIS CR                               |                 Undetermined (information indicator)                | 11534 |
# |                               AIS CR                               |                 undetermined (information indicator)                | 11534 |
# |                                HNM                                 |                            archdeaconries                           |  9999 |
# |                                HNM                                 |                             armored cars                            |  9999 |
# |                                HNM                                 |                           inhabited places                          |  9999 |
# |                      Archaeology Data Service                      |                            archdeaconries                           |  9884 |
# |                      Archaeology Data Service                      |                             armored cars                            |  9884 |
# |                      Archaeology Data Service                      |                           inhabited places                          |  9884 |
# |                               AIS CR                               |                               burials                               |  9115 |
# |                      Archaeology Data Service                      |                                sherds                               |  8953 |
# |                               AIS CR                               |                         field fortifications                        |  8653 |
# |                      Archaeology Data Service                      |                                walls                                |  8269 |
# | Institut national de recherches archéologiques préventives (Inrap) |                          pits (earthworks)                          |  7795 |
# |                                HNM                                 |                 Undetermined (information indicator)                |  7202 |
# |                                HNM                                 |                 undetermined (information indicator)                |  7202 |
# |                                HNM                                 |                              cemeteries                             |  6985 |
# |                               AIS CR                               |                         topographic surveys                         |  6682 |
# |                      Archaeology Data Service                      |                              boundaries                             |  6533 |
# |                      Archaeology Data Service                      |                       agricultural settlements                      |  6377 |
# |                               AIS CR                               |                         physical activities                         |  6332 |
# |                      Archaeology Data Service                      |                               LITHICS                               |  5965 |
# |                      Archaeology Data Service                      |                               lithics                               |  5965 |
# |                               AIS CR                               |                         fieldwork (research)                        |  5905 |
# |                      Archaeology Data Service                      |                               burials                               |  5884 |
# |                      Archaeology Data Service                      |                                roads                                |  5796 |
# |                      Archaeology Data Service                      |                     posts (structural elements)                     |  5555 |
# |        International Association for Classical Archaeology         |                        buildings (structures)                       |  5548 |
# | Institut national de recherches archéologiques préventives (Inrap) |                     industry (object groupings)                     |  5421 |
# |                               AIS CR                               |                                other                                |  5246 |
# |                               AIS CR                               |                    other (information indicator)                    |  5246 |
# |                               AIS CR                               |                         cultural landscapes                         |  5214 |
# |        International Association for Classical Archaeology         |                              cemeteries                             |  5019 |
# |                                HNM                                 |                                graves                               |  4871 |
# |                      Archaeology Data Service                      |                         vessels (containers)                        |  4801 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                fauna                                |  4678 |
# |                      Archaeology Data Service                      |                          physical features                          |  4628 |
# |                               AIS CR                               |                               amateurs                              |  4447 |
# |                      Archaeology Data Service                      |                        agricultural buildings                       |  4370 |
# |                      Archaeology Data Service                      |                                Houses                               |  4314 |
# |                      Archaeology Data Service                      |                                houses                               |  4314 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             plats (maps)                            |  4280 |
# |                      Archaeology Data Service                      |                          agricultural land                          |  4263 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             rural areas                             |  4255 |
# | Institut national de recherches archéologiques préventives (Inrap) |                              postholes                              |  4228 |
# |                      Archaeology Data Service                      |                               barrows                               |  4144 |
# |        International Association for Classical Archaeology         |                                Houses                               |  4128 |
# |        International Association for Classical Archaeology         |                                houses                               |  4128 |
# |                               AIS CR                               |                              production                             |  4039 |
# |                               AIS CR                               |                         production (process)                        |  4039 |
# |                      Archaeology Data Service                      |                          wells (structures)                         |  3961 |
# |                      Archaeology Data Service                      |                             water wells                             |  3959 |
# |        International Association for Classical Archaeology         |                                tombs                                |  3932 |
# |                      Archaeology Data Service                      |                              cemeteries                             |  3808 |
# |                      Archaeology Data Service                      |                               gullies                               |  3624 |
# |                                HNM                                 |                                tumuli                               |  3533 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             agriculture                             |  3512 |
# | Institut national de recherches archéologiques préventives (Inrap) |                       agriculture (discipline)                      |  3512 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                roads                                |  3500 |
# |                      Archaeology Data Service                      |                    earthworks (engineering works)                   |  3447 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               hearths                               |  3432 |
# |                               AIS CR                               |                   research centers (institutions)                   |  3212 |
# |                      Archaeology Data Service                      |                                barns                                |  3149 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                walls                                |  2978 |
# |                      Archaeology Data Service                      |                                paths                                |  2824 |
# |                      Archaeology Data Service                      |                          pots (containers)                          |  2821 |
# |                               AIS CR                               |                               fighting                              |  2700 |
# |                      Archaeology Data Service                      |                                farms                                |  2699 |
# | Institut national de recherches archéologiques préventives (Inrap) |                            archdeaconries                           |  2687 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             armored cars                            |  2687 |
# | Institut national de recherches archéologiques préventives (Inrap) |                           inhabited places                          |  2687 |
# |                                HNM                                 |                               churches                              |  2606 |
# |                                HNM                                 |                         churches (buildings)                        |  2606 |
# | Institut national de recherches archéologiques préventives (Inrap) |                   silos (agricultural structures)                   |  2548 |
# |                                HNM                                 |                        buildings (structures)                       |  2515 |
# |                               AIS CR                               |                   public services (organizations)                   |  2440 |
# |        International Association for Classical Archaeology         |                                roads                                |  2412 |
# | Institut national de recherches archéologiques préventives (Inrap) |                          wells (structures)                         |  2410 |
# |                      Archaeology Data Service                      |                   quarries (extracting complexes)                   |  2380 |
# |                      Archaeology Data Service                      |                                kilns                                |  2373 |
# |                      Archaeology Data Service                      |                         cellars (storerooms)                        |  2363 |
# |                      Archaeology Data Service                      |                         dumps (refuse areas)                        |  2345 |
# |        International Association for Classical Archaeology         |                            fortifications                           |  2296 |
# |        International Association for Classical Archaeology         |                  fortifications (built environment)                 |  2296 |
# |        International Association for Classical Archaeology         |                                kilns                                |  2244 |
# |                        IDACOR (CONICET/UNC)                        |                         Archaeological sites                        |  2218 |
# |                        IDACOR (CONICET/UNC)                        |                         archaeological sites                        |  2218 |
# |                        IDACOR (CONICET/UNC)                        |                         archeaological sites                        |  2218 |
# |                      Archaeology Data Service                      |                              city walls                             |  2122 |
# | Institut national de recherches archéologiques préventives (Inrap) |                           glass (material)                          |  2100 |
# |                      Archaeology Data Service                      |                       castles (fortifications)                      |  2091 |
# | Institut national de recherches archéologiques préventives (Inrap) |                       architectural terracotta                      |  2089 |
# |                      Archaeology Data Service                      |                            human remains                            |  2036 |
# |                      Archaeology Data Service                      |                              cremations                             |  2021 |
# |                               AIS CR                               |                 other works (information indicator)                 |  2019 |
# |        International Association for Classical Archaeology         |                            archdeaconries                           |  1975 |
# |        International Association for Classical Archaeology         |                             armored cars                            |  1975 |
# |        International Association for Classical Archaeology         |                           inhabited places                          |  1975 |
# | Institut national de recherches archéologiques préventives (Inrap) |               skeleton components (animal components)               |  1950 |
# |        International Association for Classical Archaeology         |               sanctuaries (religious building spaces)               |  1943 |
# | Institut national de recherches archéologiques préventives (Inrap) |                        fences (site elements)                       |  1910 |
# | Institut national de recherches archéologiques préventives (Inrap) |                              hydraulics                             |  1886 |
# |                      Archaeology Data Service                      |                                forts                                |  1878 |
# |                      Archaeology Data Service                      |                         yards (open spaces)                         |  1838 |
# |                      Archaeology Data Service                      |                           tile (material)                           |  1806 |
# |                      Archaeology Data Service                      |                           tile (materials)                          |  1806 |
# |                      Archaeology Data Service                      |                      floors (surface elements)                      |  1783 |
# |                      Archaeology Data Service                      |                                towns                                |  1717 |
# |                      Archaeology Data Service                      |                     mines (extracting complexes)                    |  1710 |
# |                      Archaeology Data Service                      |                     mines (extractive complexes)                    |  1710 |
# |                      Archaeology Data Service                      |                         Archaeological sites                        |  1705 |
# |                      Archaeology Data Service                      |                         archaeological sites                        |  1705 |
# |                      Archaeology Data Service                      |                         archeaological sites                        |  1705 |
# |                      Archaeology Data Service                      |                               hearths                               |  1691 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             anthropology                            |  1663 |
# | Institut national de recherches archéologiques préventives (Inrap) |                           drainage piping                           |  1658 |
# |        International Association for Classical Archaeology         |                             public baths                            |  1658 |
# |                                HNM                                 |                               villages                              |  1639 |
# |                      Archaeology Data Service                      |                             ring ditches                            |  1627 |
# |        International Association for Classical Archaeology         |                    cisterns (plumbing components)                   |  1625 |
# |                      Archaeology Data Service                      |                                villas                               |  1605 |
# |                        IDACOR (CONICET/UNC)                        |                          prehistoric sites                          |  1567 |
# |                      Archaeology Data Service                      |                              farmhouses                             |  1564 |
# |        International Association for Classical Archaeology         |                          wells (structures)                         |  1525 |
# | Institut national de recherches archéologiques préventives (Inrap) |                            COINS (MONEY)                            |  1505 |
# | Institut national de recherches archéologiques préventives (Inrap) |                            coins (money)                            |  1505 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             embankments                             |  1487 |
# |        International Association for Classical Archaeology         |                               churches                              |  1484 |
# |        International Association for Classical Archaeology         |                         churches (buildings)                        |  1484 |
# | Institut national de recherches archéologiques préventives (Inrap) |                         crafts (art genres)                         |  1440 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                Houses                               |  1438 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                houses                               |  1438 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                scoria                               |  1436 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                 soil                                |  1435 |
# |                      Archaeology Data Service                      |                            COINS (MONEY)                            |  1403 |
# |                      Archaeology Data Service                      |                            coins (money)                            |  1403 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               burials                               |  1389 |
# |                      Archaeology Data Service                      |                           glass (material)                          |  1378 |
# |        International Association for Classical Archaeology         |                            public spaces                            |  1375 |
# | Institut national de recherches archéologiques préventives (Inrap) |                          radioactive dating                         |  1356 |
# | Institut national de recherches archéologiques préventives (Inrap) |                          radiocarbon dating                         |  1356 |
# |                      Archaeology Data Service                      |                        brick (clay material)                        |  1344 |
# |                      Archaeology Data Service                      |                         brick (clay product)                        |  1344 |
# |                      Archaeology Data Service                      |                    building brick (clay products)                   |  1344 |
# | Institut national de recherches archéologiques préventives (Inrap) |                         cellars (storerooms)                        |  1335 |
# |                      Archaeology Data Service                      |                               culverts                              |  1335 |
# |                      Archaeology Data Service                      |                    chapels (rooms or structures)                    |  1302 |
# |                               AIS CR                               |                           rituals (events)                          |  1274 |
# |                               AIS CR                               |                               storage                               |  1273 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               JEWELRY                               |  1265 |
# | Institut national de recherches archéologiques préventives (Inrap) |                              jewellery                              |  1265 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               jewelry                               |  1265 |
# |                      Archaeology Data Service                      |                              cesspools                              |  1264 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             urban design                            |  1257 |
# |                      Archaeology Data Service                      |                        gardens (open spaces)                        |  1239 |
# |        International Association for Classical Archaeology         |                           public buildings                          |  1209 |
# |        International Association for Classical Archaeology         |              public buildings (governmental buildings)              |  1209 |
# |                               AIS CR                               |                      construction (assembling)                      |  1202 |
# |                      Archaeology Data Service                      |                              hillforts                              |  1181 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                kilns                                |  1177 |
# |        International Association for Classical Archaeology         |                                farms                                |  1167 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             numismatics                             |  1155 |
# |        International Association for Classical Archaeology         |                                walls                                |  1153 |
# |                               AIS CR                               |                     universities (institutions)                     |  1148 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               land use                              |  1130 |
# |                      Archaeology Data Service                      |                    monasteries (built complexes)                    |  1108 |
# | Institut national de recherches archéologiques préventives (Inrap) |                               corrals                               |  1104 |
# | Institut national de recherches archéologiques préventives (Inrap) |                  millstones (equipment components)                  |  1104 |
# |                      Archaeology Data Service                      |                                 SLAG                                |  1078 |
# |                      Archaeology Data Service                      |                                 slag                                |  1078 |
# |                                HNM                                 |                            fortifications                           |  1072 |
# |                                HNM                                 |                  fortifications (built environment)                 |  1072 |
# |                      Archaeology Data Service                      |                            boundary walls                           |  1058 |
# |                               AIS CR                               |                   national museums (institutions)                   |  1042 |
# |                               AIS CR                               |                        architectural surveys                        |  1041 |
# | Institut national de recherches archéologiques préventives (Inrap) |                             urbanization                            |  1032 |
# |                      Archaeology Data Service                      |                       ovens (baking equipment)                      |  1022 |
# |                               AIS CR                               |                            transportation                           |  1012 |
# |                      Archaeology Data Service                      |                        flakes (object genre)                        |  1001 |
# |                      Archaeology Data Service                      |                        flakes (object genres)                       |  1001 |
# | Institut national de recherches archéologiques préventives (Inrap) |                                Tools                                |  995  |
# | Institut national de recherches archéologiques préventives (Inrap) |                                tools                                |  995  |
# |                                HNM                                 |                       castles (fortifications)                      |  985  |
# | Institut national de recherches archéologiques préventives (Inrap) |                             paleobotany                             |  973  |
# |        International Association for Classical Archaeology         |                                towns                                |  955  |
# |                      Archaeology Data Service                      |                          banks (landforms)                          |  948  |
# | Institut national de recherches archéologiques préventives (Inrap) |                      amphorae (storage vessels)                     |  944  |
# |        International Association for Classical Archaeology         |                              basilicas                              |  928  |
# |        International Association for Classical Archaeology         |                      basilicas (works by form)                      |  928  |
# |                      Archaeology Data Service                      |                                graves                               |  922  |
# |        International Association for Classical Archaeology         |                          temples (buildings                         |  920  |
# |        International Association for Classical Archaeology         |                         temples (buildings)                         |  920  |
# |                      Archaeology Data Service                      |                           drainage systems                          |  918  |
# |                               AIS CR                               |                                mining                               |  917  |
# |                      Archaeology Data Service                      |                                cairns                               |  905  |
# |                      Archaeology Data Service                      |                            huts (houses)                            |  900  |
# | Institut national de recherches archéologiques préventives (Inrap) |                             roofing tile                            |  891  |
# | Institut national de recherches archéologiques préventives (Inrap) |                              glassware                              |  876  |
# | Institut national de recherches archéologiques préventives (Inrap) |                               drainage                              |  860  |
# |                      Archaeology Data Service                      |                             manor houses                            |  848  |
# |                      Archaeology Data Service                      |                             churchyards                             |  845  |
# |                                HNM                                 |                              monuments                              |  842  |
# |                                HNM                                 |                                walls                                |  838  |
# |                      Archaeology Data Service                      |                        bridges (built works)                        |  832  |
# | Institut national de recherches archéologiques préventives (Inrap) |                              granaries                              |  821  |
# |                      Archaeology Data Service                      |                           industrial sites                          |  799  |
# |                      Archaeology Data Service                      |                         vaults (tomb spaces)                        |  787  |
# |                      Archaeology Data Service                      |                                 pubs                                |  777  |
# |                      Archaeology Data Service                      |                         schools (buildings)                         |  754  |
# | Institut national de recherches archéologiques préventives (Inrap) |                            huts (houses)                            |  734  |
# |                                HNM                                 |                              waterworks                             |  732  |
# |                      Archaeology Data Service                      |                            country houses                           |  727  |
# |                               AIS CR                               |                         geophysical surveys                         |  723  |
# |                      Archaeology Data Service                      |                         abbeys (monasteries)                        |  714  |
# |                      Archaeology Data Service                      |                               villages                              |  705  |
# |        International Association for Classical Archaeology         |                          business districts                         |  696  |
# |                      Archaeology Data Service                      |                             flint (rock)                            |  676  |
# |                      Archaeology Data Service                      |                         deserted settlements                        |  668  |
# |                      Archaeology Data Service                      |                        Quaker meeting houses                        |  662  |
# |        International Association for Classical Archaeology         |                         ports (settlements)                         |  660  |
# |                      Archaeology Data Service                      |                      pipes (smoking equipment)                      |  642  |
# |                      Archaeology Data Service                      |                             roofing tile                            |  636  |
# |                      Archaeology Data Service                      |                             ironworking                             |  630  |
# |                      Archaeology Data Service                      |                                mounds                               |  629  |
# |                      Archaeology Data Service                      |                        architectural elements                       |  625  |
# |                      Archaeology Data Service                      |                        factories (structures)                       |  625  |
# |                               AIS CR                               |                            archaeologists                           |  623  |
# |                                HNM                                 |                                roads                                |  616  |
# |                      Archaeology Data Service                      |                     fragments (object portions)                     |  610  |
# | Institut national de recherches archéologiques préventives (Inrap) |                         frescoes (paintings)                        |  606  |
# | Institut national de recherches archéologiques préventives (Inrap) |                          dating (measuring)                         |  603  |
# |                      Archaeology Data Service                      |              hospitals (buildings for health facility)              |  597  |
# |                      Archaeology Data Service                      |                          ceramic (material)                         |  589  |
# |                               AIS CR                               |                               sampling                              |  584  |
# |                                HNM                                 |                                villas                               |  575  |
# | Institut national de recherches archéologiques préventives (Inrap) |                             flint (rock)                            |  562  |
# | Institut national de recherches archéologiques préventives (Inrap) |                              homesteads                             |  560  |
# | Institut national de recherches archéologiques préventives (Inrap) |                         palisades (outworks)                        |  559  |
# |                               AIS CR                               |                     utilities (infrastructures)                     |  555  |
# | Institut national de recherches archéologiques préventives (Inrap) |                            boundary walls                           |  554  |
# | Institut national de recherches archéologiques préventives (Inrap) |                              fireplaces                             |  554  |
# |                      Archaeology Data Service                      |                              warehouses                             |  552  |
# |                      Archaeology Data Service                      |                             watercourses                            |  551  |
# |                      Archaeology Data Service                      |                             sunken huts                             |  547  |
# | Institut national de recherches archéologiques préventives (Inrap) |                               FIBULAE                               |  541  |
# | Institut national de recherches archéologiques préventives (Inrap) |                               Fibulae                               |  541  |
# | Institut national de recherches archéologiques préventives (Inrap) |                               fibulae                               |  541  |
# |        International Association for Classical Archaeology         |                                villas                               |  540  |
# |                                HNM                                 |                        fortified settlements                        |  539  |
# | Institut national de recherches archéologiques préventives (Inrap) |                       channels (water bodies)                       |  534  |
# |                      Archaeology Data Service                      |                          garden structures                          |  531  |
# |                      Archaeology Data Service                      |                          canals (waterways)                         |  517  |
# |        International Association for Classical Archaeology         |                                caves                                |  511  |
# | Institut national de recherches archéologiques préventives (Inrap) |                      EARLY WESTERN WORLD COINS                      |  510  |
# | Institut national de recherches archéologiques préventives (Inrap) |                      Early Western World coins                      |  510  |
# |                      Archaeology Data Service                      |                   manors (agricultural complexes)                   |  505  |
# | Institut national de recherches archéologiques préventives (Inrap) |                            wood charcoal                            |  503  |
# |                      Archaeology Data Service                      |                               friaries                              |  502  |
# |                      Archaeology Data Service                      |                              lime kilns                             |  500  |
# | Institut national de recherches archéologiques préventives (Inrap) |                       archives (institutions)                       |  493  |
# | Institut national de recherches archéologiques préventives (Inrap) |                                 daub                                |  490  |
# |                      Archaeology Data Service                      |                    furnaces (heating components)                    |  489  |
# |                      Archaeology Data Service                      |                         industrial buildings                        |  489  |
# |                      Archaeology Data Service                      |                               BROOCHES                              |  487  |
# |                      Archaeology Data Service                      |                               brooches                              |  487  |
# |                      Archaeology Data Service                      |                                querns                               |  482  |
# |                        IDACOR (CONICET/UNC)                        |                               villages                              |  482  |
# | Institut national de recherches archéologiques préventives (Inrap) |                               ditches                               |  470  |
# |                      Archaeology Data Service                      |                              frontiers                              |  469  |
# |                      Archaeology Data Service                      |                            plant material                           |  468  |
# |                                HNM                                 |                      springs (bodies of water)                      |  462  |
# |                      Archaeology Data Service                      |                              saltworks                              |  461  |
# |                      Archaeology Data Service                      |                               trenches                              |  457  |
# |                      Archaeology Data Service                      |                       workshops (work spaces)                       |  455  |
# |                                HNM                                 |                               ditches                               |  452  |
# | Institut national de recherches archéologiques préventives (Inrap) |                            fortifications                           |  449  |
# | Institut national de recherches archéologiques préventives (Inrap) |                  fortifications (built environment)                 |  449  |
# |                      Archaeology Data Service                      |                          air raid shelters                          |  444  |
# |                      Archaeology Data Service                      |                         megalithic monuments                        |  444  |
# |                        IDACOR (CONICET/UNC)                        |                       mortars (grinding tools)                      |  444  |
# | Institut national de recherches archéologiques préventives (Inrap) |                     posts (structural elements)                     |  442  |
# |                        IDACOR (CONICET/UNC)                        |                            rock shelters                            |  438  |
# |                      Archaeology Data Service                      |                             water mills                             |  431  |
# |                      Archaeology Data Service                      |                       channels (water bodies)                       |  430  |
# |                      Archaeology Data Service                      |                       artifacts (object genre)                      |  429  |
# |                      Archaeology Data Service                      |                            formal gardens                           |  428  |
# |        International Association for Classical Archaeology         |                         theaters (buildings)                        |  428  |
# |                      Archaeology Data Service                      |                                 vici                                |  425  |
# |                      Archaeology Data Service                      |                              crematoria                             |  421  |
# |                      Archaeology Data Service                      |                             crematories                             |  421  |
# | Institut national de recherches archéologiques préventives (Inrap) |                         ballast (aggregate)                         |  416  |
# | Institut national de recherches archéologiques préventives (Inrap) |                        gardens (open spaces)                        |  413  |
# | Institut national de recherches archéologiques préventives (Inrap) |                             stratigraphy                            |  413  |
# |                      Archaeology Data Service                      |                           tenement houses                           |  411  |
# |        International Association for Classical Archaeology         |                                tumuli                               |  406  |
# |                      Archaeology Data Service                      |                              airfields                              |  403  |
# |        International Association for Classical Archaeology         |                    monasteries (built complexes)                    |  399  |
# |        International Association for Classical Archaeology         |                        fortified settlements                        |  397  |
# | Institut national de recherches archéologiques préventives (Inrap) |                            archaeobotany                            |  396  |
# |                      Archaeology Data Service                      |                        defense installations                        |  390  |
# |                      Archaeology Data Service                      |                      railroads (infrastructure)                     |  387  |
# |                      Archaeology Data Service                      |                       railway (infrastructure)                      |  387  |
# |                      Archaeology Data Service                      |                               wharves                               |  382  |
# |                      Archaeology Data Service                      |                             gravel pits                             |  381  |
# |                      Archaeology Data Service                      |                            terrace houses                           |  379  |
# |                      Archaeology Data Service                      |                              gatehouses                             |  378  |
# | Institut national de recherches archéologiques préventives (Inrap) |                         extracting complexes                        |  375  |
# | Institut national de recherches archéologiques préventives (Inrap) |                        extracting complexes/                        |  375  |
# ...
# |                               CENIEH                               |                           raptors (birds)                           |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                relics                               |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                          religious (people)                         |   1   |
# |                      Archaeology Data Service                      |                          religious objects                          |   1   |
# |                               CENIEH                               |                         research (documents)                        |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                        restoration (process)                        |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                      retables (altar appendage)                     |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                   retouch (archaeological concept)                  |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                rites                                |   1   |
# |                               CENIEH                               |                             ritual pits                             |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                routes                               |   1   |
# |                      Archaeology Data Service                      |                            royal chapels                            |   1   |
# |                      Archaeology Data Service                      |                      runways (airport runways)                      |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                sabers                               |   1   |
# |                               CENIEH                               |                              sacrifices                             |   1   |
# |                               CENIEH                               |                  sacrifices (religious ceremonies)                  |   1   |
# |        International Association for Classical Archaeology         |                              salt mines                             |   1   |
# |        International Association for Classical Archaeology         |                              saltworks                              |   1   |
# |                               CENIEH                               |                               sampling                              |   1   |
# |                      Archaeology Data Service                      |                           satellite towns                           |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                              saucepans                              |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                               savannas                              |   1   |
# |                      Archaeology Data Service                      |                              scabbards                              |   1   |
# |                      Archaeology Data Service                      |                              scaffolds                              |   1   |
# |                               CENIEH                               |                     scanning electron microscopy                    |   1   |
# |                      Archaeology Data Service                      |                   scarps (fortification elements)                   |   1   |
# |                      Archaeology Data Service                      |                              schooners                              |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                          sealing (process)                          |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                 seas                                |   1   |
# |                               CENIEH                               |                             seasonality                             |   1   |
# |                      Archaeology Data Service                      |                          seating furniture                          |   1   |
# |                               CENIEH                               |                            sedimentology                            |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                            sedimentology                            |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                         serpentine (mineral)                        |   1   |
# |                               CENIEH                               |                         settlement patterns                         |   1   |
# |                      Archaeology Data Service                      |                               shackles                              |   1   |
# |                               CENIEH                               |                       shell (animal material)                       |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                              shipwrecks                             |   1   |
# |                               CENIEH                               |                           sinks (fixtures)                          |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                           site protection                           |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                     skin (collagenous material)                     |   1   |
# |                      Archaeology Data Service                      |                         slabs (flat objects)                        |   1   |
# |                               CENIEH                               |                     slabs (structural elements)                     |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                               smelting                              |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                            social history                           |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                           social structure                          |   1   |
# |                               CENIEH                               |                                sonar                                |   1   |
# |                               CENIEH                               |                      sources (general concept)                      |   1   |
# |                      Archaeology Data Service                      |                                spalls                               |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                spices                               |   1   |
# |                      Archaeology Data Service                      |                 spindles (textile working equipment)                |   1   |
# |                      Archaeology Data Service                      |                           sports complexes                          |   1   |
# |                               CENIEH                               |                       stable isotope analysis                       |   1   |
# |                      Archaeology Data Service                      |                           staves (boards)                           |   1   |
# |                      Archaeology Data Service                      |                                stores                               |   1   |
# |                               CENIEH                               |                          strontium isotopes                         |   1   |
# |                      Archaeology Data Service                      |                           submarine bases                           |   1   |
# |                      Archaeology Data Service                      |                            summer palaces                           |   1   |
# |                      Archaeology Data Service                      |                             supermarkets                            |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                        synagogues (buildings)                       |   1   |
# |                               CENIEH                               |                             talus slopes                            |   1   |
# |                      Archaeology Data Service                      |                      targets (sports equipment)                     |   1   |
# |                      Archaeology Data Service                      |                               taxiways                              |   1   |
# |                      Archaeology Data Service                      |                             tennis clubs                            |   1   |
# |                               CENIEH                               |                            territoriality                           |   1   |
# |                      Archaeology Data Service                      |                      textile working equipment                      |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                                tholoi                               |   1   |
# |                      Archaeology Data Service                      |                          threshing machines                         |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                            throwing axes                            |   1   |
# |                               CENIEH                               |                                tills                                |   1   |
# |                      Archaeology Data Service                      |                             tin (metal)                             |   1   |
# |                      Archaeology Data Service                      |                             toll bridges                            |   1   |
# |                               CENIEH                               |                           tooth (material)                          |   1   |
# |                               CENIEH                               |                              toothpicks                             |   1   |
# |                               CENIEH                               |                              tortoises                              |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                              torturing                              |   1   |
# |                      Archaeology Data Service                      |                            trade centers                            |   1   |
# |                      Archaeology Data Service                      |                             transformers                            |   1   |
# |                      Archaeology Data Service                      |                       transportation buildings                      |   1   |
# |                      Archaeology Data Service                      |                              treadmills                             |   1   |
# |                      Archaeology Data Service                      |                        triangulation stations                       |   1   |
# |                      Archaeology Data Service                      |                              turnstiles                             |   1   |
# |                               CENIEH                               |                               typology                              |   1   |
# |                      Archaeology Data Service                      |                             union halls                             |   1   |
# |                               CENIEH                               |                        uranium-series dating                        |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                        uranium-thorium dating                       |   1   |
# |                      Archaeology Data Service                      |                                vases                                |   1   |
# |                      Archaeology Data Service                      |                          vegetable gardens                          |   1   |
# |                      Archaeology Data Service                      |                              velodromes                             |   1   |
# |                               CENIEH                               |                         virtual restoration                         |   1   |
# |                      Archaeology Data Service                      |                          vocational schools                         |   1   |
# |                      Archaeology Data Service                      |                    vocational schools (buildings)                   |   1   |
# |                      Archaeology Data Service                      |                            waiting rooms                            |   1   |
# |                      Archaeology Data Service                      |                          washing (cleaning)                         |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                      water (inorganic material)                     |   1   |
# |                      Archaeology Data Service                      |                    water distribution structures                    |   1   |
# |                        IDACOR (CONICET/UNC)                        |                             water mills                             |   1   |
# |                      Archaeology Data Service                      |                            water tunnels                            |   1   |
# |                      Archaeology Data Service                      |                           weighing devices                          |   1   |
# |                        IDACOR (CONICET/UNC)                        |                             well wheels                             |   1   |
# |                               CENIEH                               |                               wetlands                              |   1   |
# |                      Archaeology Data Service                      |                               winches                               |   1   |
# |                      Archaeology Data Service                      |                          wind power plants                          |   1   |
# |                      Archaeology Data Service                      |                              windlasses                             |   1   |
# |                      Archaeology Data Service                      |                              woodsheds                              |   1   |
# | Institut national de recherches archéologiques préventives (Inrap) |                          x-ray fluorescence                         |   1   |
# +--------------------------------------------------------------------+---------------------------------------------------------------------+-------+
